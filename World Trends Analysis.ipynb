# %% [markdown]
# # WORLD DEMOGRAPHIC DATA ANALYSIS
#
# Ananlysis of demographic data amongst multiple countries in the world. The data set entials: country names, country codes, birth rates, intenet usage rates and income levels and groupings of the countries.

# %%
import pandas as pd
stats = pd.read_csv("Demographic-Data.csv")

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
### Exploring Data

# checking number of rows for tacability
len(stats) # 195 rows imported
# Out:
# 195

# %%
# Viewing Columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
# Number of Columns
len(stats.columns)
# Out:
# 5

# %%
# top rows
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# bottom rows

stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# informaion on the columns
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# statistics on columns
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
# subsetting datasets (Rows, Columns and Combining the two)

# %%
# Subseting Rows
stats[0:26]
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 0                    Aruba          ABW      10.244        78.90000
# 1              Afghanistan          AFG      35.253         5.90000
# 2                   Angola          AGO      45.985        19.10000
# 3                  Albania          ALB      12.877        57.20000
# 4     United Arab Emirates          ARE      11.044        88.00000
# 5                Argentina          ARG      17.716        59.90000
# 6                  Armenia          ARM      13.308        41.90000
# 7      Antigua and Barbuda          ATG      16.447        63.40000
# 8                Australia          AUS      13.200        83.00000
# 9                  Austria          AUT       9.400        80.61880
# 10              Azerbaijan          AZE      18.300        58.70000
# 11                 Burundi          BDI      44.151         1.30000
# 12                 Belgium          BEL      11.200        82.17020
# ...

# %%
#Getting every Nth row - in this case N = 5 

stats[:: 5]
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 0                    Aruba          ABW      10.244       78.900000
# 5                Argentina          ARG      17.716       59.900000
# 10              Azerbaijan          AZE      18.300       58.700000
# 15              Bangladesh          BGD      20.142        6.630000
# 20                 Belarus          BLR      12.500       54.170000
# 25                Barbados          BRB      12.188       73.000000
# 30                  Canada          CAN      10.900       85.800000
# 35                Cameroon          CMR      37.236        6.400000
# 40              Costa Rica          CRI      15.022       45.960000
# 45                 Germany          DEU       8.500       84.170000
# 50                 Ecuador          ECU      21.070       40.353684
# 55                Ethiopia          ETH      32.925        1.900000
# 60                   Gabon          GAB      30.555        9.200000
# ...

# %%
# Subsetting Columns
stats[['Country Name','Birth rate']]
# Out:
#              Country Name  Birth rate
# 0                   Aruba      10.244
# 1             Afghanistan      35.253
# 2                  Angola      45.985
# 3                 Albania      12.877
# 4    United Arab Emirates      11.044
# ..                    ...         ...
# 190           Yemen, Rep.      32.947
# 191          South Africa      20.850
# 192      Congo, Dem. Rep.      42.394
# 193                Zambia      40.471
# 194              Zimbabwe      35.715
#
# [195 rows x 2 columns]

# %%
# subsetting and combining columns within a specific range
stats[['Country Name','Birth rate']][4:50]
# Out:
#                 Country Name  Birth rate
# 4       United Arab Emirates      11.044
# 5                  Argentina      17.716
# 6                    Armenia      13.308
# 7        Antigua and Barbuda      16.447
# 8                  Australia      13.200
# 9                    Austria       9.400
# 10                Azerbaijan      18.300
# 11                   Burundi      44.151
# 12                   Belgium      11.200
# 13                     Benin      36.440
# 14              Burkina Faso      40.551
# 15                Bangladesh      20.142
# 16                  Bulgaria       9.200
# 17                   Bahrain      15.040
# 18              Bahamas, The      15.339
# 19    Bosnia and Herzegovina       9.062
# 20                   Belarus      12.500
# 21                    Belize      23.092
# 22                   Bermuda      10.400
# 23                   Bolivia      24.236
# 24                    Brazil      14.931
# 25                  Barbados      12.188
# ...

# %%
# Filtering Data Frames
IU = stats['Internet users'] < 2
IU[0:50]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Internet users, dtype: bool

# %%
# Filter countries based on internet usage levels of less than 2%
stats[IU]
# Out:
#      Country Name Country Code  Birth rate  Internet users  \
# 11        Burundi          BDI      44.151             1.3
# 52        Eritrea          ERI      34.800             0.9
# 55       Ethiopia          ETH      32.925             1.9
# 64         Guinea          GIN      37.337             1.6
# 117       Myanmar          MMR      18.119             1.6
# 127         Niger          NER      49.661             1.7
# 154  Sierra Leone          SLE      36.729             1.7
# 156       Somalia          SOM      43.891             1.5
# 172   Timor-Leste          TLS      35.755             1.1
#
#             Income Group
# 11            Low income
# 52            Low income
# 55            Low income
# 64            Low income
# 117  Lower middle income
# 127           Low income
# 154           Low income
# 156           Low income
# 172  Lower middle income

# %% [markdown]
# Output is made up of countries with Internet usage statistics that positively matched to the condition of having an internet usage of less than 2%

# %%
#Gettting countries with  birth rate that is greater than 40
BR = stats['Birth rate'] > 40
stats[BR]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 2              Angola          AGO      45.985            19.1
# 11            Burundi          BDI      44.151             1.3
# 14       Burkina Faso          BFA      40.551             9.1
# 65        Gambia, The          GMB      42.525            14.0
# 115              Mali          MLI      44.138             3.5
# 127             Niger          NER      49.661             1.7
# 128           Nigeria          NGA      40.045            38.0
# 156           Somalia          SOM      43.891             1.5
# 167              Chad          TCD      45.745             2.3
# 178            Uganda          UGA      43.474            16.2
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
#
#             Income Group
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# ...

# %%
# Getting countries with Birth rates greater than 40 and Intenet Usage that is less than 2
stats[(stats['Birth rate'] > 40) & (stats['Internet users'] < 2)]
# IU & BR
# stats[IU & BR]
# Out:
#     Country Name Country Code  Birth rate  Internet users Income Group
# 11       Burundi          BDI      44.151             1.3   Low income
# 127        Niger          NER      49.661             1.7   Low income
# 156      Somalia          SOM      43.891             1.5   Low income

# %% [markdown]
# Countries with a high birth rate and low rates of internet penetration and usage

# %%
# Getting hihg income countries
IG = stats['Income Group'] == 'High income'
stats[IG]
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 0                    Aruba          ABW      10.244           78.90
# 4     United Arab Emirates          ARE      11.044           88.00
# 5                Argentina          ARG      17.716           59.90
# 7      Antigua and Barbuda          ATG      16.447           63.40
# 8                Australia          AUS      13.200           83.00
# ..                     ...          ...         ...             ...
# 174    Trinidad and Tobago          TTO      14.590           63.80
# 180                Uruguay          URY      14.374           57.69
# 181          United States          USA      12.500           84.20
# 184          Venezuela, RB          VEN      19.842           54.90
# 185  Virgin Islands (U.S.)          VIR      10.700           45.30
#
#     Income Group
# 0    High income
# 4    High income
# 5    High income
# 7    High income
# 8    High income
# ..           ...
# 174  High income
# ...

# %%
#Statistics of countries with High Income Levels
stats[IG].describe().transpose()
# Out:
#                 count       mean        std   min      25%   50%     75%  \
# Birth rate       67.0  12.753433   4.467886   7.9  10.1000  11.3  14.545
# Internet users   67.0  74.231684  14.333237  16.4  65.6274  74.1  84.485
#
#                     max
# Birth rate      35.3620
# Internet users  96.5468

# %%
# Getting Upper middle income countries
UM = stats['Income Group'] == 'Upper middle income'
stats[UM]
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 2                            Angola          AGO      45.985       19.100000
# 3                           Albania          ALB      12.877       57.200000
# 10                       Azerbaijan          AZE      18.300       58.700000
# 16                         Bulgaria          BGR       9.200       53.061500
# 19           Bosnia and Herzegovina          BIH       9.062       57.790000
# 20                          Belarus          BLR      12.500       54.170000
# 21                           Belize          BLZ      23.092       33.600000
# 24                           Brazil          BRA      14.931       51.040000
# 28                         Botswana          BWA      25.267       15.000000
# 33                            China          CHN      12.100       45.800000
# 37                         Colombia          COL      16.076       51.700000
# ...

# %%
#statistics for countries with Upper Middle Income Levels
stats[UM].describe().transpose()
# Out:
#                 count       mean        std  min       25%      50%       75%  \
# Birth rate       48.0  18.740646   7.109501  8.8  13.28875  18.7795  21.48225
# Internet users   48.0  40.279577  15.785314  9.2  32.68750  43.6300  51.55000
#
#                    max
# Birth rate      45.985
# Internet users  70.500

# %%
# Getting Lower middle income countries
LM = stats['Income Group'] == 'Lower middle income'
stats[LM]
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 6                  Armenia          ARM      13.308         41.9000
# 15              Bangladesh          BGD      20.142          6.6300
# 23                 Bolivia          BOL      24.236         36.9400
# 27                  Bhutan          BTN      18.134         29.9000
# 34           Cote d'Ivoire          CIV      37.320          8.4000
# 35                Cameroon          CMR      37.236          6.4000
# 36             Congo, Rep.          COG      37.011          6.6000
# 39              Cabo Verde          CPV      21.625         37.5000
# 46                Djibouti          DJI      25.486          9.5000
# 51        Egypt, Arab Rep.          EGY      28.032         29.4000
# 59   Micronesia, Fed. Sts.          FSM      23.511         27.8000
# 62                 Georgia          GEO      13.332         43.3000
# 63                   Ghana          GHA      33.131         12.3000
# ...

# %%
# Statistics for countries with lower middle income levels
stats[LM].describe().transpose()
# Out:
#                 count       mean        std   min       25%     50%       75%  \
# Birth rate       50.0  26.309140   7.705661  11.1  20.41975  26.895  32.40825
# Internet users   50.0  22.366386  14.001846   1.1  11.35000  19.850  36.45500
#
#                    max
# Birth rate      40.471
# Internet users  56.000

# %%
# Getting Low income countries
LI = stats['Income Group'] == 'Low income'
stats[LI]
# Out:
#                  Country Name Country Code  Birth rate  Internet users  \
# 1                 Afghanistan          AFG      35.253            5.90
# 11                    Burundi          BDI      44.151            1.30
# 13                      Benin          BEN      36.440            4.90
# 14               Burkina Faso          BFA      40.551            9.10
# 29   Central African Republic          CAF      34.076            3.50
# 38                    Comoros          COM      34.326            6.50
# 52                    Eritrea          ERI      34.800            0.90
# 55                   Ethiopia          ETH      32.925            1.90
# 64                     Guinea          GIN      37.337            1.60
# 65                Gambia, The          GMB      42.525           14.00
# 66              Guinea-Bissau          GNB      37.503            3.10
# 77                      Haiti          HTI      25.345           10.60
# ...

# %%
# Statistics of countries with low income levels
stats[LI].describe().transpose()
# Out:
#                 count       mean       std     min      25%      50%  \
# Birth rate       30.0  37.238267  6.268684  20.923  34.7145  36.9275
# Internet users   30.0   5.988333  4.907835   0.900   2.2250   4.4500
#
#                      75%     max
# Birth rate      41.93325  49.661
# Internet users   8.45000  18.500

# %%
# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")
# %matplotlib inline 
plt.rcParams['figure.figsize'] = 8,5
import warnings
warnings.filterwarnings('ignore')

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Distribution
vis1 = sns.distplot(stats['Internet users'], bins=30)

# %%
vis2 = sns.boxplot(data=stats, x='Income Group', y="Birth rate")

# %% [markdown]
# Majoriy of the high income countries have a birth rate of 12 with a couple of outlies having both a high income and a high birth rate of 35.
#
# Majority of low income countries have high birth rates of 37 with the first quartile ranging from 25-35, the second quartile ranging from 35-37 and the forth quartile ranging from 42-49.HOwever there is an ouliter having both low income levels and a low birth rate of 20.
#
# Birth rates of Upper middle income countries range from 10-33, with majority being at 28 and an outlier being at 47.
#
# Lower middle income countries have a birth rate rangine between 12-43 with and average birth rate of 26.

# %%
# Birthrate to Internet users linear regression model
vis3 = sns.lmplot(data=stats, x='Internet users', y='Birth rate',
                  fit_reg =False, hue='Income Group', size=7, aspect=2,
                 scatter_kws={'s':100})

# %% [markdown]
# The graph illustrates lower birth rates corresponding to high internet usage levels indicating that on average, birth rates decerease as internet usage levels increase.
#
# All countries with low income levels have high birth rates and low numbers of internet users. Lower middle income countries are fairly distributed from average to high rates of birth with their internet usage numbers topping out in the mid 40's with one outlier in the mid 50's.
#
# Upper middle income coiuntries  have birth rates ranging from low to medium levels, peaking at 30 with internet user naumber rangin from 15%-70% with most of the countries having internet user number s rangin from 25%-50%.
#
# High income countries have low birth rates ranging from 5%-20%, with one outlier having a high birth rate of 35%. Their internet user numbers range from 42%-98% with one outlier, the one with a high birth rate having low a internet user level at 18%.
